# %% [markdown]
# [![Ava Colabis](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/adlerpriit/2025_taka_fall/blob/review/python-notebooks/teemad/python/Pandas.ipynb)

# %% [markdown]
# # Tabelandmed Pandasega
#
# Pandas on Pythoni teek tabelandmete töötlemiseks. Siin õpid andmeid laadima ja kontrollima, ridu valima, uusi veerge arvutama ning rühmade kokkuvõtteid koostama.
#
# **Eeldused:** oskad kasutada listi, sõnastikku, tingimust ja funktsiooni ning lugeda punktiga meetodikutset. Vajaduse korral korda [Intro](Intro.ipynb) põhiosa. **Iseseisev töö:** ligikaudu 70 minutit. Põhiosa on P1–P6; P7–P9 on valikuline lisamaterjal.
#
# Näited ja harjutused kasutavad sama andmestikku. Näidete käivitamine ei sõltu harjutuste lahendamisest. [Lahenduskäigud](lahendused/Pandas_lahendused.md) ava pärast oma katset.

# %% [markdown]
# <a id="p1"></a>
# ## P1. Andmete laadimine
#
# Käsk `import pandas as pd` annab teegile lühinime `pd`. `pd.read_csv()` loeb CSV-faili **DataFrame'iks** ehk andmetabeliks. CSV on tekstifail, mille iga rida on kirje ja väljad on siin eraldatud komadega.
#
# Järgmine lahter otsib faili repo `data` kaustast. Kui kohalikku faili pole, kasutatakse kursuse andmestiku kindlat veebiversiooni. Väljastatud allika järgi näed, kust andmed loeti. Käivita see lahter ka siis, kui alustad hiljem pooleli jäänud harjutusest.
#
# `display()` kuvab tabeli vormindatult. Ka lahtri viimane avaldis kuvatakse automaatselt; mitme tulemuse jaoks kasuta `display()` või `print()`.

# %%
from pathlib import Path
import pandas as pd
from IPython.display import display

# Proovi esmalt repo juurkausta, seejärel töövihiku kausta suhtelist teed.
andmefail = Path("data/Islander_data.csv")
if not andmefail.is_file():
    andmefail = Path("../../data/Islander_data.csv")

if andmefail.is_file():
    allikas = andmefail
else:
    allikas = "https://raw.githubusercontent.com/adlerpriit/2025_taka_fall/37b50eb8474faeeb0993c2d4883680bee0560cbd/data/Islander_data.csv"

print("Andmete allikas:", allikas)
print("Pandase versioon:", pd.__version__)
algandmed = pd.read_csv(allikas)
display(algandmed.head())

# %% [markdown]
# Andmestikus on virtuaalsete katseisikute mälukatse tulemused. Üks lähterida kirjeldab ühe katseisiku mõõtmisi enne ja pärast katset. `age` on vanus, `Drug` ravimirühm ja `Dosage` annusetase. `Happy_Sad_group` eristab rõõmsate (`H`) ja kurbade (`S`) mälestuste rühma.
#
# `Diff = Mem_Score_After − Mem_Score_Before`. Positiivne väärtus tähendab **skoori suurenemist**, negatiivne vähenemist. See ei tähenda mõõdiku täpse selgituseta automaatselt mälu paranemist. Ravimikoodid on `A` alprasolaam, `T` triasolaam ja `S` platseebo.
#
# Täielik [andmekirjeldus ja allikaviide](../../data/README.md) on repo andmekaustas. Hoia `algandmed` muutmata ning tee teisendused töökoopias.

# %% [markdown]
# <a id="p2"></a>
# ## P2. Tabel, veerg ja andmete kontroll
#
# **DataFrame** on kahemõõtmeline tabel. Üks veerg on enamasti **Series** ehk indekseeritud väärtuste jada. Indeks tähistab ridu; vaikimisi on see täisarvude jada alates nullist.
#
# Alusta väikese tabeliga. Sõnastiku võtmetest saavad veerunimed ja listidest veergude väärtused. Veergude pikkused peavad klappima.

# %%
inimesed = pd.DataFrame({
    "nimi": ["Mari", "Jaan", "Liis", "Peeter"],
    "vanus": [24, 38, 29, 46],
    "linn": ["Tartu", "Tallinn", "Tartu", "Pärnu"],
})
display(inimesed)
display(inimesed["vanus"])

# %% [markdown]
# Andmetabeli uurimisel küsi kõigepealt: mida üks rida tähendab, millised veerud on olemas ning kas väärtused on sobivat tüüpi?
#
# - `.head(n)` kuvab esimesed `n` rida.
# - `.shape` annab ridade ja veergude arvu. See on atribuut, mistõttu sulge pole.
# - `.info()` näitab veergude tüüpe ja olemasolevate väärtuste arvu.
# - `.describe()` annab siin arvuliste veergude statistilise kokkuvõtte.
#
# Täisarvulise veeru tüüp võib olla `int64`, kümnendarvudel `float64`. Teksti tüübinimi võib Pandase versioonist sõltuvalt olla `str`, `string` või `object`. Andmetüüp ei määra üksi tunnuse tähendust: arvuline annusetase võib analüüsis olla kategooria.

# %%
print("Ridu ja veerge:", inimesed.shape)
inimesed.info()
display(inimesed.describe())

# %% [markdown]
# <a id="p-01"></a>
#
# ### P-01
#
# Uuri tabelit `algandmed`: kuva esimesed kaheksa rida, tabeli mõõtmed ja veergude info. Nimeta kaks arvulist tunnust ning kaks tunnust, mida kasutaksid rühmade moodustamiseks.
#
# **Enesekontroll:** faili päises on üheksa veergu. Kas oskad selgitada `Drug` ja `Dosage` tähendust?

# %%
# Kirjuta siia oma kood. Vajaduse korral lisa lahtreid.

# %% [markdown]
# *Kirjuta siia oma vastus või põhjendus.*

# %% [markdown]
# <a id="p3"></a>
# ## P3. Valimine, filtreerimine ja sortimine
#
# `tabel["veerg"]` valib ühe veeru Series-objektina. `tabel[["a", "b"]]` valib veergude listi ja annab tabeli. `.loc[read, veerud]` valib ridu indeksi sildi või tingimuse järgi ning veerge nime järgi.
#
# Tingimus `inimesed["vanus"] >= 30` annab iga rea kohta tõeväärtuse. Filtris säilivad read, mille tingimus on tõene.

# %%
display(inimesed[["nimi", "vanus"]])
display(inimesed["vanus"] >= 30)
vahemalt_30 = inimesed.loc[inimesed["vanus"] >= 30, ["nimi", "linn"]]
display(vahemalt_30)

# %% [markdown]
# Pandase veergude tingimusi ühenda märkidega `&` (ja), `|` (või) ja `~` (eitus). Pane iga võrdlus sulgudesse. Pythoni `and` ja `or` ei sobi tervete tõeväärtusveergude ühendamiseks.
#
# `.sort_values()` järjestab read valitud veeru järgi. `ascending=False` annab kahaneva järjekorra. See tagastab uue tabeli; algtabel jääb samaks.

# %%
tartu_valik = inimesed.loc[
    (inimesed["linn"] == "Tartu") & (inimesed["vanus"] > 25),
    ["nimi", "vanus"],
]
display(tartu_valik)
display(algandmed.sort_values("Diff", ascending=False).head(5))

# %% [markdown]
# <a id="p-02"></a>
#
# ### P-02
#
# Koosta tabelist `algandmed` kaks eraldi valikut:
#
# 1. Osalejad, kelle vanus on üle 30 ja perekonnanimi `Durand`.
# 2. Osalejad ravimirühmast `A`, kelle annusetase on 3.
#
# Kuva kummagi valiku ridade arv. Sorteeri teine valik `Diff` järgi kahanevalt.
#
# **Vihje:** ridade arvu saad `len(tabel)` abil. **Enesekontroll:** kontrolli valitud veergude väärtusi; ükski rida ei tohi tingimust rikkuda. `Diff` esimene väärtus peab olema vähemalt sama suur kui viimane.

# %%
# Kirjuta siia oma kood. Vajaduse korral lisa lahtreid.

# %% [markdown]
# *Kirjuta siia oma vastus või põhjendus.*

# %% [markdown]
# <a id="p4"></a>
# ## P4. Uus veerg ja puuduvad väärtused
#
# `.copy()` loob töökoopia. Uue veeru saad sellele omistamisega lisada. Veergudega arvutades tehakse sama tehe kõigi ridade jaoks; eraldi Pythoni tsüklit pole vaja.

# %%
andmed = algandmed.copy()
andmed["arvutatud_muutus"] = andmed["Mem_Score_After"] - andmed["Mem_Score_Before"]
andmed["skoor_suurenes"] = andmed["Diff"] > 0
display(andmed[["Mem_Score_Before", "Mem_Score_After", "Diff", "arvutatud_muutus", "skoor_suurenes"]].head())

# %% [markdown]
# `.isna()` leiab puuduvad väärtused; `.sum()` loendab tõeseid väärtusi veeruti. Andmete puudumine ei tähenda nulli. Enne eemaldamist või täitmist selgita välja, millised read muutuksid ja kuidas see analüüsi mõjutab.
#
# Allpool on eraldi näidistabel, kus üks vanus puudub. `.dropna(subset=["vanus"])` jätab kõrvale ainult puuduva vanusega read. See on sobiv siis, kui just vanus on vastatava küsimuse jaoks vajalik.

# %%
display(algandmed.isna().sum())
naide = pd.DataFrame({"nimi": ["Mari", "Jaan"], "vanus": [24, None]})
display(naide)
display(naide.dropna(subset=["vanus"]))

# %% [markdown]
# <a id="p-03"></a>
#
# ### P-03
#
# Loo `algandmed` põhjal oma koopia. Lisa tõeväärtusveerg `muutus_vahemalt_10`, mis märgib read, kus `Diff >= 10`. Loenda sellised read. Kontrolli ka puuduvate `Diff`-väärtuste arvu.
#
# **Vihje:** tõeväärtusveeru `.sum()` loendab `True`-väärtusi. **Enesekontroll:** kas kasutad õiget veerunime ja kas piirväärtus 10 on kaasatud? Selgita, miks `False` ei tähenda puuduvat väärtust.

# %%
# Kirjuta siia oma kood. Vajaduse korral lisa lahtreid.

# %% [markdown]
# *Kirjuta siia oma vastus või põhjendus.*

# %% [markdown]
# <a id="p5"></a>
# ## P5. Rühmade kokkuvõte
#
# `groupby()` jagab read rühmadeks. `.agg()` arvutab iga rühma jaoks kokkuvõtte. Allolevas kirjes `keskmine_muutus=("Diff", "mean")` on vasakul väljundveeru nimi ning paremal lähteveerg ja arvutusviis.
#
# `mean` on keskmine, `median` mediaan, `size` ridade arv. `count` loendab ainult valitud veeru mittepuuduvaid väärtusi. Keskmise juurde lisa alati rühma suurus, et näeksid, kui paljudel vaatlustel tulemus põhineb.

# %%
kokkuvote = algandmed.groupby("Drug").agg(
    keskmine_muutus=("Diff", "mean"),
    mediaan=("Diff", "median"),
    ridu=("Diff", "size"),
    skooriga_ridu=("Diff", "count"),
).reset_index()
display(kokkuvote.round(2))

# %% [markdown]
# `.reset_index()` toob rühmitamistunnuse tagasi tavaliseks veeruks. `.round(2)` ümardab kuvatava koopia väärtusi; algsed arvutused säilivad muutujas `kokkuvote`.
#
# Siin on `size` ja `count` võrdsed, sest `Diff` ei puudu. Allolevas väikeses näites erinevad need arvud.

# %%
puuduvusega = pd.DataFrame({"ruhm": ["A", "A", "B"], "skoor": [5, None, 8]})
display(puuduvusega.groupby("ruhm").agg(ridu=("skoor", "size"), skooriga_ridu=("skoor", "count")))

# %% [markdown]
# <a id="p-04"></a>
#
# ### P-04
#
# Rühmita `algandmed` annusetaseme (`Dosage`) järgi. Leia iga rühma keskmine `Diff` ja ridade arv. Millise rühma keskmine on suurim? Mida üks kokkuvõttetabeli rida tähistab?
#
# **Enesekontroll:** rühmade ridade arvude summa peab võrduma algtabeli ridade arvuga. Põhjenda, miks see tabel üksi ei tõesta annuse põhjuslikku mõju.

# %%
# Kirjuta siia oma kood. Vajaduse korral lisa lahtreid.

# %% [markdown]
# *Kirjuta siia oma vastus või põhjendus.*

# %% [markdown]
# <a id="p6"></a>
# ## P6. Tulemuse salvestamine
#
# Salvesta kokkuvõte CSV-faili. `index=False` jätab tehnilise reaindeksi failist välja. Faili kordussalvestamine sama nimega asendab eelmise sisu. Korda pärast salvestamist faili lugemist, et näha, mida edasi jagad.

# %%
kaust = Path("valjund")
kaust.mkdir(exist_ok=True)
fail = kaust / "ravimiruhmade_kokkuvote.csv"
kokkuvote.to_csv(fail, index=False)
print("Salvestatud:", fail.resolve())
display(pd.read_csv(fail))

# %% [markdown]
# <a id="p-05"></a>
#
# ### P-05
#
# Vasta tekstilahtris:
#
# 1. Mille poolest erinevad `.shape` ja `.head()`?
# 2. Millal annavad `size` ja `count` eri tulemuse?
# 3. Miks on filtris `(df["age"] > 30) & (df["Drug"] == "A")` mõlemad tingimused sulgudes?
#
# **Enesekontroll:** leia iga vastuse juurde sobiv näide põhiosast.

# %%
# Kirjuta siia oma kood. Vajaduse korral lisa lahtreid.

# %% [markdown]
# *Kirjuta siia oma vastus või põhjendus.*

# %% [markdown]
# Põhiosa on läbitud. Edasi liigu [Seaborni vihikusse](Seaborn.ipynb). Vajaduse korral võrdle [lahenduskäikudega](lahendused/Pandas_lahendused.md).
#
# Järgmised peatükid on lisamaterjal. Nende vahelejätmine ei takista visualiseerimist ega lõpuülesannet.

# %% [markdown]
# <a id="p7"></a>
# ## P7. Lisamaterjal: tabelite liitmine
#
# `merge()` ühendab tabeleid võtme väärtuse järgi. Lisame ravimikoodile nimetuse. `how="left"` säilitab vasakpoolse tabeli read. `validate="many_to_one"` kontrollib, et parempoolses tabelis vastab igale võtmele kõige rohkem üks rida.
#
# Pärast liitmist kontrolli ridade arvu ja puuduvate vastete arvu. Korduv võti parempoolses tabelis võib muidu ridu mitmekordistada.
#
# Kontrollis leiab `.notna()` olemasolevad väärtused ja `.all()` nõuab, et tingimus kehtiks igal real.

# %%
ravimid = pd.DataFrame({
    "Drug": ["A", "T", "S"],
    "ravim": ["Alprasolaam", "Triasolaam", "Platseebo"],
})
nimedega = algandmed.merge(ravimid, on="Drug", how="left", validate="many_to_one")
assert len(nimedega) == len(algandmed)
assert nimedega["ravim"].notna().all()
display(nimedega.head())

# %% [markdown]
# <a id="p-l1"></a>
#
# ### P-L1
#
# Loo vastavustabel veeru `Happy_Sad_group` koodide `H` ja `S` jaoks. Lisa nimetused `"Rõõmsad"` ja `"Kurvad"` algandmetele uude veergu `malestused`.
#
# **Enesekontroll:** ridade arv ei muutu ja uues veerus pole puuduvaid väärtusi.

# %%
# Kirjuta siia oma kood. Vajaduse korral lisa lahtreid.

# %% [markdown]
# *Kirjuta siia oma vastus või põhjendus.*

# %% [markdown]
# `concat()` ühendab tabeleid ridade või veergude kaupa. Ridade kaupa ühendamine sobib sama struktuuriga tabelitele. Veergude kaupa ühendamisel joondatakse read **indeksi**, mitte üksnes reapositsiooni järgi.
#
# `.iloc[]` valib täisarvulise positsiooni järgi. Näiteks `.iloc[:2]` valib esimesed kaks rida, olenemata nende indeksi siltidest.

# %%
algus = algandmed.iloc[:2]
lopp = algandmed.iloc[2:]
taastatud = pd.concat([algus, lopp], ignore_index=True)
assert taastatud.equals(algandmed)
print("Taastatud ridu:", len(taastatud))

# %% [markdown]
# <a id="p8"></a>
# ## P8. Lisamaterjal: lai ja pikk tabel
#
# Laias tabelis on enne- ja pärastmõõtmine eraldi veergudes. Pikas tabelis on mõõtmise liik oma veerus ja skoor oma veerus. `.melt()` teeb laia tabeli pikaks.
#
# `id_vars` jätab alles rea kirjeldavad tunnused, `value_vars` valib kokku tõstetavad mõõtmised. `var_name` ja `value_name` nimetavad uued veerud. Lisa enne teisendamist lähterea tunnus: korduvad nimed ei ole unikaalne võti. See tunnus tähistab siin faili rida, mitte sõltumatult kontrollitud isikutunnust.
#
# Kontrollis loendab `.size()` iga lähterea mõõtmised, `.eq(2)` võrdleb arvu kahega ja `.all()` kontrollib kõiki ridu.

# %%
lai = algandmed.copy()
lai["rea_id"] = range(len(lai))
pikk = lai.melt(
    id_vars=["rea_id", "Drug", "Dosage"],
    value_vars=["Mem_Score_Before", "Mem_Score_After"],
    var_name="mootmine",
    value_name="skoor",
)
display(pikk.head())
print("Ridu:", len(pikk))
assert pikk.groupby("rea_id").size().eq(2).all()

# %% [markdown]
# `pivot_table()` teeb rühmitatud kokkuvõttest risttabeli. Erinevalt `pivot()`-ist saab see sama võtmekombinatsiooni mitu väärtust kokku võtta. `pivot()` vajab unikaalseid võtmekombinatsioone; kõik võimalikud kombinatsioonid ei pea esinema.

# %%
risttabel = algandmed.pivot_table(
    index="Drug", columns="Dosage", values="Diff", aggfunc="mean", observed=True
)
display(risttabel.round(2))

# %% [markdown]
# <a id="p-l2"></a>
#
# ### P-L2
#
# Tee `algandmed` põhjal pikk tabel, kus enne- ja pärastmõõtmine on veerus `skoor`. Säilita ka lähterea tunnus ja `Happy_Sad_group`. Kontrolli, et iga lähterida annab kaks mõõtmist.
#
# **Enesekontroll:** ridade arv kahekordistub. `Diff` ei ole kolmas ajahetk ja seda mõõtmiste hulka ei lisata.

# %%
# Kirjuta siia oma kood. Vajaduse korral lisa lahtreid.

# %% [markdown]
# *Kirjuta siia oma vastus või põhjendus.*

# %% [markdown]
# <a id="p9"></a>
# ## P9. Lisamaterjal: vanuserühmad ja töötlusahel
#
# `pd.cut()` jagab arvtunnuse vahemikeks. Allpool kuulub esimene rühm vahemikku 0–35, järgmine üle 35 kuni 50 jne. `right=True` kaasab ülemise piiri; `include_lowest=True` kaasab ka esimese alumise piiri. Vahemikke katavad sildid peavad vastama piiridele.

# %%
vanustega = algandmed.copy()
vanustega["vanuseruhm"] = pd.cut(
    vanustega["age"],
    bins=[0, 35, 50, 65, float("inf")],
    labels=["kuni 35", "36–50", "51–65", "66+"],
    right=True,
    include_lowest=True,
)
display(vanustega["vanuseruhm"].value_counts(sort=False))
assert vanustega["vanuseruhm"].notna().all()

# %% [markdown]
# <a id="p-l3"></a>
#
# ### P-L3
#
# Kontrolli sama vanuserühmade jaotust väärtustega `[24, 35, 36, 50, 51, 65, 66, 83]`. Põhjenda, millisesse rühma kuuluvad 35 ja 36.
#
# **Enesekontroll:** ühelgi kontrollväärtusel ei tohi rühm puududa; 24 peab saama sildiks `"kuni 35"`.

# %%
# Kirjuta siia oma kood. Vajaduse korral lisa lahtreid.

# %% [markdown]
# *Kirjuta siia oma vastus või põhjendus.*

# %% [markdown]
# `.pipe()` annab tabeli järgmisele funktsioonile. `.assign()` loob uue veeruga tabeli. Allolev ahel on valikuline viis töötluse sammude nimetamiseks; sama saab teha tavaliste vahemuutujatega.

# %%
def lisa_muutus(tabel):
    return tabel.assign(muutus=tabel["Mem_Score_After"] - tabel["Mem_Score_Before"])

toodeldud = algandmed.pipe(lisa_muutus).sort_values("muutus")
display(toodeldud.head())

# %% [markdown]
# ## Edasi lugemiseks
#
# - [Pandase algõpetus](https://pandas.pydata.org/docs/getting_started/intro_tutorials/index.html) — otsi sama töötlussammu kohta teine näide.
# - [DataFrame'i teatmik](https://pandas.pydata.org/docs/reference/frame.html) — meetodite parameetrid.
#
# Kontrolli dokumentatsiooni versiooni. Oma versiooni näed `pd.__version__` kaudu.
